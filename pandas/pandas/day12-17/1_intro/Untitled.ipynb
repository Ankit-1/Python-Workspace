# %%
import pandas as pd
df = pd.read_csv('nyc_weather.csv') #to read csv files in pandas
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['Temperature']
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['Events']=='Rain'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27    False
# 28    False
# 29    False
# 30    False
# Name: Events, dtype: bool

# %%
df[df['Events']=='Rain']
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 9              109
# 15             340
# 26             311

# %%
df[df['Temperature']==30]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 13  1/14/2016           30        12        47                 29.95
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 13               10           5.0               T           7    NaN
#
#     WindDirDegrees
# 13             266

# %%
df[df['Events']=='Rain'] + df[df['Events']=='Snow']
# Out:
#     EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8   NaN          NaN       NaN       NaN                   NaN
# 9   NaN          NaN       NaN       NaN                   NaN
# 15  NaN          NaN       NaN       NaN                   NaN
# 17  NaN          NaN       NaN       NaN                   NaN
# 21  NaN          NaN       NaN       NaN                   NaN
# 23  NaN          NaN       NaN       NaN                   NaN
# 26  NaN          NaN       NaN       NaN                   NaN
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8               NaN           NaN             NaN         NaN    NaN
# 9               NaN           NaN             NaN         NaN    NaN
# 15              NaN           NaN             NaN         NaN    NaN
# 17              NaN           NaN             NaN         NaN    NaN
# 21              NaN           NaN             NaN         NaN    NaN
# ...

# %%
df[df['Events']=='Rain']  
df[df['Events']=='Snow']
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 17  1/18/2016           25         6        53                 29.83
# 21  1/22/2016           26         6        41                 30.21
# 23  1/24/2016           28        11        53                 29.92
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 17                9          12.0               T           2   Snow
# 21                9           NaN            0.01           3   Snow
# 23                8           6.0               T           3   Snow
#
#     WindDirDegrees
# 17             293
# 21              34
# 23             327

# %%
df['Events']='NaN'-[df[df['Events']=='Rain'] + df[df['Events']=='Snow']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-fa8f87828bf0> in <module>()
# ----> 1 df['Events']='NaN'-[df[df['Events']=='Rain'] + df[df['Events']=='Snow']]
#
# TypeError: unsupported operand type(s) for -: 'str' and 'list'

# %%
df['Events']=='NaN'- [df[df['Events']=='Rain'] + df[df['Events']=='Snow']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-b442a22c5344> in <module>()
# ----> 1 df['Events']=='NaN'- [df[df['Events']=='Rain'] + df[df['Events']=='Snow']]
#
# TypeError: unsupported operand type(s) for -: 'str' and 'list'

# %%
df[df['Events']=='NaN']- [df[df['Events']=='Rain'] + df[df['Events']=='Snow']]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-65bd431ded28> in <module>()
# ----> 1 df[df['Events']=='NaN']- [df[df['Events']=='Rain'] + df[df['Events']=='Snow']]
#
# C:\Users\TheBOT\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\ops.py in f(self, other, axis, level, fill_value)
#    1229     def f(self, other, axis=default_axis, level=None, fill_value=None):
#    1230
# -> 1231         other = _align_method_FRAME(self, other, axis)
#    1232
#    1233         if isinstance(other, pd.DataFrame):  # Another DataFrame
#
# C:\Users\TheBOT\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\ops.py in _align_method_FRAME(left, right, axis)
#    1147
#    1148     if isinstance(right, (list, tuple)):
# -> 1149         right = to_series(right)
#    1150
# ...

# %%
df(df['Events']=='Rain'] | df[df['Events']=='Snow')
# Out:
#   File "<ipython-input-24-b98d23326836>", line 1
#     df(df['Events']=='Rain'] | df[df['Events']=='Snow')
#                            ^
# SyntaxError: invalid syntax

# %%
df(df['Events']=='Rain') + df(df['Events']=='Snow')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-d0d29aaec71e> in <module>()
# ----> 1 df(df['Events']=='Rain') + df(df['Events']=='Snow')
#
# TypeError: 'DataFrame' object is not callable

# %%
df[df['Events']=='Rain') + df(df['Events']=='Snow')
# Out:
#   File "<ipython-input-26-11c940485966>", line 1
#     df[df['Events']=='Rain') + df(df['Events']=='Snow')
#                            ^
# SyntaxError: invalid syntax

# %%
df[(df['Events']=='Rain') + (df['Events']=='Snow')]
# Out:
# C:\Users\TheBOT\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\computation\expressions.py:183: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   unsupported[op_str]))
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 17  1/18/2016           25         6        53                 29.83
# 21  1/22/2016           26         6        41                 30.21
# 23  1/24/2016           28        11        53                 29.92
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# ...

# %%
df[['Temperature','EST']]
# Out:
#     Temperature        EST
# 0            38   1/1/2016
# 1            36   1/2/2016
# 2            40   1/3/2016
# 3            25   1/4/2016
# 4            20   1/5/2016
# 5            33   1/6/2016
# 6            39   1/7/2016
# 7            39   1/8/2016
# 8            44   1/9/2016
# 9            50  1/10/2016
# 10           33  1/11/2016
# 11           35  1/12/2016
# 12           26  1/13/2016
# 13           30  1/14/2016
# 14           43  1/15/2016
# 15           47  1/16/2016
# 16           36  1/17/2016
# 17           25  1/18/2016
# 18           22  1/19/2016
# 19           32  1/20/2016
# 20           31  1/21/2016
# 21           26  1/22/2016
# 22           26  1/23/2016
# 23           28  1/24/2016
# 24           34  1/25/2016
# 25           43  1/26/2016
# 26           41  1/27/2016
# 27           37  1/28/2016
# 28           36  1/29/2016
# 29           34  1/30/2016
# 30           46  1/31/2016

# %%
df1=df[['Temperature','EST']][(df['Events']=='Rain') | (df['Events']=='Snow')]
df1
# Out:
#     Temperature        EST
# 8            44   1/9/2016
# 9            50  1/10/2016
# 15           47  1/16/2016
# 17           25  1/18/2016
# 21           26  1/22/2016
# 23           28  1/24/2016
# 26           41  1/27/2016

# %%
df.fillna(0,inplace=True)
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
# EST                     31 non-null object
# Temperature             31 non-null int64
# DewPoint                31 non-null int64
# Humidity                31 non-null int64
# Sea Level PressureIn    31 non-null float64
# VisibilityMiles         31 non-null int64
# WindSpeedMPH            31 non-null float64
# PrecipitationIn         31 non-null object
# CloudCover              31 non-null int64
# Events                  31 non-null object
# WindDirDegrees          31 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.7+ KB

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %%
df['WindSpeedMPH'].std()
# Out:
# 3.4225689904841445
